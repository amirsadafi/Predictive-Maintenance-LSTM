# %%
# Preprocessing Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tqdm.notebook import tqdm_notebook

dataset_train = pd.read_csv('https://raw.githubusercontent.com/amirsadafi/Predictive-Maintenance-LSTM/main/train_modified2.csv')
dataset_test = pd.read_csv('https://raw.githubusercontent.com/amirsadafi/Predictive-Maintenance-LSTM/main/test_modified2.csv')
# dataset_test.head(5)

# OK
dataset_train.drop(['Date' ,'Time','model','RUL_I','failure'],axis=1, inplace=True)
dataset_test.drop(['model','RUL_I','failure'],axis=1, inplace=True)

# by execute this, you would be able to Predict Failure CATEGORIES
# dataset_train.drop(['Date' ,'Time','model','RUL_I','failed'],axis=1, inplace=True)
# dataset_test.drop(['model','RUL_I','failed'],axis=1, inplace=True)
